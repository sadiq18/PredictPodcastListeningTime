# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/drawing-with-llms/train.csv
# /kaggle/input/drawing-with-llms/questions.parquet
# /kaggle/input/drawing-with-llms/kaggle_evaluation/svg_constraints.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/svg.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/svg_gateway.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/test.csv
# /kaggle/input/drawing-with-llms/kaggle_evaluation/__init__.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/templates.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/base_gateway.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/relay.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/kaggle_evaluation.proto
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/__init__.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/generated/kaggle_evaluation_pb2.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/generated/kaggle_evaluation_pb2_grpc.py
# /kaggle/input/drawing-with-llms/kaggle_evaluation/core/generated/__init__.py

# %%
import kagglehub
import polars as pl

train_path = kagglehub.competition_download('drawing-with-llms', 'train.csv')
train = pl.read_csv(train_path)

train.head()
# Out:
# shape: (5, 2)
# ┌────────┬─────────────────────────────────┐
# │ id     ┆ description                     │
# │ ---    ┆ ---                             │
# │ str    ┆ str                             │
# ╞════════╪═════════════════════════════════╡
# │ 02d892 ┆ a purple forest at dusk         │
# │ 0dcd2e ┆ gray wool coat with a faux fur… │
# │ 1e9ac1 ┆ a lighthouse overlooking the o… │
# │ 2b25db ┆ burgundy corduroy pants with p… │
# │ 4e6a54 ┆ orange corduroy overalls        │
# └────────┴─────────────────────────────────┘

# %%
train["description"][0]
# Out:
# 'a purple forest at dusk'

# %%
train["description"][1]
# Out:
# 'gray wool coat with a faux fur collar'

# %%
train["description"][3]
# Out:
# 'burgundy corduroy pants with patch pockets and silver buttons'

# %%
train["description"][4]
# Out:
# 'orange corduroy overalls'

# %%
import pandas as pd

# Read the Parquet file
df = pd.read_parquet("/kaggle/input/drawing-with-llms/questions.parquet")

# Display the dataframe
df.head()
# Out:
#        id                                          question  \
# 0  02d892            What is the main setting of the image?
# 1  02d892            Is there anything purple in the image?
# 2  02d892       What time of day is suggested in the image?
# 3  02d892  What color is prominently featured in the image?
# 4  0dcd2e                           What color is the coat?
#
#                              choices  answer
# 0  [beach, desert, forest, mountain]  forest
# 1                          [no, yes]     yes
# 2     [dawn, dusk, midday, midnight]    dusk
# 3     [green, orange, purple, white]  purple
# 4           [blue, brown, gray, red]    gray

# %%
df.shape
# Out:
# (60, 4)
